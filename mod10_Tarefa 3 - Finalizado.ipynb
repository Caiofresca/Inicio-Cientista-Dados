# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
import numpy as np
import sklearn

# %%
df = pd.read_csv('previsao_de_renda.csv')

df.drop(columns=['Unnamed: 0', 'index'], inplace=True)

print(df.head())
# Out:
#      data_ref sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0  2015-01-01    F             False             True           1
# 1  2015-01-01    M              True             True           0
# 2  2015-01-01    M              True             True           2
# 3  2015-01-01    F              True            False           0
# 4  2015-01-01    M             False            False           0
#
#     tipo_renda           educacao estado_civil tipo_residencia  idade  \
# 0  Assalariado         Secundário       Casado            Casa     36
# 1   Empresário         Secundário       Casado            Casa     42
# 2  Assalariado  Superior completo       Casado            Casa     31
# 3   Empresário         Secundário       Casado            Casa     50
# 4  Assalariado         Secundário       Casado            Casa     52
#
#    tempo_emprego  qt_pessoas_residencia    mau    renda
# 0       3.575342                    3.0  False  3369.24
# ...

# %%
qualitative_vars = ["sexo", "posse_de_veiculo", "posse_de_imovel", "tipo_renda", "educacao", "estado_civil", "tipo_residencia"]

for var in qualitative_vars:
    plt.figure(figsize=(12, 6))
    plt.title(f"Distribuição de {var} ao longo do tempo")
    sns.countplot(x='data_ref', hue=var, data=df)
    plt.xticks(rotation=45)
    plt.xlabel("Data de Referência")
    plt.ylabel("Contagem")
    plt.legend(loc='upper right')
    plt.show()

# %% [markdown]
# Educação ao longo do tempo houve uma variação, após a data 01-08-2015 o ensino secundário diminuiu bastante e o ensino superior completo aumentou significativamente seu valor.

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
df = pd.read_csv('previsao_de_renda.csv')

df['data_ref'] = pd.to_datetime(df['data_ref'])

qualitative_vars = ["sexo", "posse_de_veiculo", "posse_de_imovel", "tipo_renda", "educacao", "estado_civil", "tipo_residencia"]

plt.figure(figsize=(30, 30))

for i, var in enumerate(qualitative_vars, 1):
    plt.subplot(3, 3, i)
    sns.barplot(x='data_ref', y='renda', hue=var, data=df)
    plt.title(f"Médias de Renda por {var}")
    plt.xlabel("Data de Referência")
    plt.ylabel("Média de Renda")
    plt.xticks(rotation=45)
    plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# Os gráficos que mais tem valores diferentes são Media de renda por Educação e o Medias de renda por tipo_residencia, há valores que variam muito, mas é possivel utilizar as variáveis sim para uma modelagem.
