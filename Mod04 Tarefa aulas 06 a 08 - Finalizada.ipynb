# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
data_json = r.json()
df = pd.DataFrame(data_json['items'])
df
# Out:
#       id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 0         22864        Município     Campina da Lagoa   4103909  PR
# 1         18111        Município          Três Barras   4218301  SC
# 2         16875        Município             Arvoredo   4201653  SC
# 3         15031        Município  Bom Jardim da Serra   4202503  SC
# 4         22869        Município               Esteio   4307708  RS
# ...         ...              ...                  ...       ...  ..
# 4995       9035        Município                União   2211100  PI
# 4996       9040        Município       Alto Jequitibá   3153509  MG
# 4997       6791        Município                Braga   4302600  RS
# 4998       6307        Município         Antônio João   5000906  MS
# 4999       6309        Município        Carmo da Mata   3114006  MG
#
#                    num_pvl                          status  \
# 0     00000.000000/2033-26                        Deferido
# 1                     None                        Deferido
# 2                     None                        Deferido
# 3                     None                       Arquivado
# 4     00000.000000/2031-95  Arquivado por decurso de prazo
# ...                    ...                             ...
# 4995                  None                       Arquivado
# 4996                  None                       Arquivado
# 4997                  None                        Deferido
# 4998                  None                       Arquivado
# 4999                  None                    Regularizado
#
#               num_processo        data_protocolo                tipo_operacao  \
# 0     17944.000766/2016-11  2016-06-07T03:00:00Z  Operação contratual interna
# 1     19406.000700/2008-25  2008-08-01T03:00:00Z  Operação contratual interna
# 2     19406.000372/2007-86  2007-09-26T03:00:00Z  Operação contratual interna
# 3     19406.000134/2005-17  2006-05-04T03:00:00Z  Operação contratual interna
# 4     17944.000774/2016-59  2016-09-23T03:00:00Z  Operação contratual interna
# ...                    ...                   ...                          ...
# 4995  17944.000890/2008-68  2008-04-03T03:00:00Z  Operação contratual interna
# 4996  17944.000891/2008-11  2008-12-23T02:00:00Z  Operação contratual interna
# 4997  17944.000430/2013-05  2013-07-05T03:00:00Z  Operação contratual interna
# 4998  17944.000317/2009-35  2009-03-30T03:00:00Z  Operação contratual interna
# 4999  17944.000317/2011-50  2016-04-13T03:00:00Z  Operação contratual interna
#
#                                           finalidade  \
# 0                                     Infraestrutura
# 1                                     Infraestrutura
# 2     Aquisição de máquinas, equipamentos e veículos
# 3     Aquisição de máquinas, equipamentos e veículos
# 4                                     Infraestrutura
# ...                                              ...
# 4995                             Caminho da Escola 2
# 4996                             Caminho da Escola 2
# 4997                                  Infraestrutura
# 4998                                         Provias
# 4999      Regularização de Dívida - Energia Elétrica
#
#                           tipo_credor  \
# 0     Instituição Financeira Nacional
# 1     Instituição Financeira Nacional
# 2     Instituição Financeira Nacional
# 3     Instituição Financeira Nacional
# 4     Instituição Financeira Nacional
# ...                               ...
# 4995  Instituição Financeira Nacional
# 4996  Instituição Financeira Nacional
# 4997  Instituição Financeira Nacional
# 4998  Instituição Financeira Nacional
# 4999                  Empresa Estatal
#
#                                                  credor moeda       valor  \
# 0                      Agência de Fomento do Paraná S/A  Real  1600000.00
# 1     Agência de Fomento do Estado de Santa Catarina...  Real  2500000.00
# 2     Agência de Fomento do Estado de Santa Catarina...  Real   164000.00
# 3     Agência de Fomento do Estado de Santa Catarina...  Real   250000.00
# 4     BADESUL Desenvolvimento S.A. - Agência de Fome...  Real  2000000.00
# ...                                                 ...   ...         ...
# 4995                            Caixa Econômica Federal  Real   598900.00
# 4996                                Banco do Brasil S/A  Real   367500.00
# 4997  BADESUL Desenvolvimento S.A. - Agência de Fome...  Real   700000.00
# 4998                            Caixa Econômica Federal  Real   350000.00
# 4999           Companhia Energética de Minas Gerais S/A  Real   377318.34
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 0                    1                      0  17/06/2016
# 1                    0                      0  05/08/2008
# 2                    1                      0  18/10/2007
# 3                    0                      0  18/05/2006
# 4                    0                      0  13/02/2017
# ...                ...                    ...         ...
# 4995                 0                      0  26/08/2008
# 4996                 0                      0  09/02/2009
# 4997                 1                      0  16/07/2013
# 4998                 0                      0  08/04/2009
# 4999                 1                      0  03/05/2016
#
# [5000 rows x 18 columns]

# %%
pvl_rj = df['uf']== 'RJ'

# %%
pvl_rj.value_counts()
# Out:
# uf
# False    4942
# True       58
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['id_pleito', 'tipo_interessado', 'interessado', 'cod_ibge', 'uf',
#        'num_pvl', 'status', 'num_processo', 'data_protocolo', 'tipo_operacao',
#        'finalidade', 'tipo_credor', 'credor', 'moeda', 'valor',
#        'pvl_assoc_divida', 'pvl_contradado_credor', 'data_status'],
#       dtype='object')

# %%
# 2) Seu código aqui
df['status'].value_counts().head(3)
# Out:
# status
# Deferido             2481
# Deferido (PVL-IF)    1306
# Arquivado             377
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              5000 non-null   int64
#  1   tipo_interessado       5000 non-null   object
#  2   interessado            5000 non-null   object
#  3   cod_ibge               5000 non-null   int64
#  4   uf                     5000 non-null   object
#  5   num_pvl                2428 non-null   object
#  6   status                 5000 non-null   object
#  7   num_processo           3650 non-null   object
#  8   data_protocolo         3650 non-null   object
#  9   tipo_operacao          5000 non-null   object
#  10  finalidade             5000 non-null   object
#  11  tipo_credor            5000 non-null   object
#  12  credor                 5000 non-null   object
#  13  moeda                  5000 non-null   object
#  14  valor                  5000 non-null   float64
#  15  pvl_assoc_divida       5000 non-null   int64
#  16  pvl_contradado_credor  5000 non-null   int64
#  17  data_status            5000 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 703.3+ KB

# %%
df['data_status'].head()
# Out:
# 0    17/06/2016
# 1    05/08/2008
# 2    18/10/2007
# 3    18/05/2006
# 4    13/02/2017
# Name: data_status, dtype: object

# %%
df['ano'] = df['data_status'].str.extract('(\d{4})')

# %%
df['ano'].head()
# Out:
# 0    2016
# 1    2008
# 2    2007
# 3    2006
# 4    2017
# Name: ano, dtype: object

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_dados(uf, tipo_interessado):
    dados_filtrados = df[(df['uf'] == uf) & (df['tipo_interessado'] == tipo_interessado)]
    return dados_filtrados

# %%
uf_consulta = 'SP'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta
# Out:
#       id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 75         8098           Estado   São Paulo        35  SP
# 494       67164           Estado   São Paulo        35  SP
# 1131      11390           Estado   São Paulo        35  SP
# 1355       5317           Estado   São Paulo        35  SP
# 1747      11638           Estado   São Paulo        35  SP
# 1774      67621           Estado   São Paulo        35  SP
# 2536       6985           Estado   São Paulo        35  SP
# 2677      48051           Estado   São Paulo        35  SP
# 2935       5688           Estado   São Paulo        35  SP
# 3384       7118           Estado   São Paulo        35  SP
# 3708       4931           Estado   São Paulo        35  SP
# 3921       5223           Estado   São Paulo        35  SP
# 4919       6536           Estado   São Paulo        35  SP
#
#                    num_pvl                                             status  \
# 75                    None                                           Deferido
# 494   PVL02.003925/2023-97                         Em retificação pelo credor
# 1131                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1355                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1747                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1774  PVL02.004327/2023-35                    Em retificação pelo interessado
# 2536                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2677  PVL02.002802/2021-77  Encaminhado à PGFN com manifestação técnica fa...
# 2935                  None                                           Deferido
# 3384                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3708                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3921                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4919                  None                                           Deferido
#
#               num_processo        data_protocolo  \
# 75    17944.000712/2012-13  2012-05-14T03:00:00Z
# 494   17944.105321/2023-47  2023-11-23T15:52:31Z
# 1131  17944.001430/2010-71  2011-03-14T03:00:00Z
# 1355  17944.000084/2014-38  2014-01-23T02:00:00Z
# 1747  17944.001493/2009-94  2009-12-17T02:00:00Z
# 1774  17944.000023/2024-42  2023-12-28T16:06:15Z
# 2536  17944.000473/2006-53  2007-02-28T03:00:00Z
# 2677  17944.103753/2021-51  2022-05-27T21:34:28Z
# 2935  17944.000173/2004-11  2004-04-12T03:00:00Z
# 3384  17944.000501/2013-61  2014-01-23T02:00:00Z
# 3708  10951.001032/2003-98  2003-12-12T02:00:00Z
# 3921  17944.000063/2010-99  2010-08-18T03:00:00Z
# 4919  17944.000375/2012-64  2012-03-16T03:00:00Z
#
#                                           tipo_operacao  \
# 75                          Operação contratual interna
# 494   Operação contratual interna (com garantia da U...
# 1131  Operação contratual externa (com garantia da U...
# 1355  Operação contratual interna (com garantia da U...
# 1747  Operação contratual interna (com garantia da U...
# 1774                        Operação contratual interna
# 2536  Operação contratual externa (com garantia da U...
# 2677  Operação contratual externa (com garantia da U...
# 2935                              Concessão de garantia
# 3384  Operação contratual externa (com garantia da U...
# 3708  Operação contratual externa (com garantia da U...
# 3921  Operação contratual externa (com garantia da U...
# 4919                        Operação contratual interna
#
#                                              finalidade  \
# 75                                       Infraestrutura
# 494                                       Aporte em PPP
# 1131                Preservação e recuperação ambiental
# 1355                                     Infraestrutura
# 1747  PEF - Programa Emergencial de Financiamento do...
# 1774                                      Aporte em PPP
# 2536                                     Multissetorial
# 2677                                     Infraestrutura
# 2935  Concessão de garantia a empresa estatal não de...
# 3384                                     Infraestrutura
# 3708                       Fortalecimento Institucional
# 3921                Preservação e recuperação ambiental
# 4919                                     Infraestrutura
#
#                                tipo_credor  \
# 75         Instituição Financeira Nacional
# 494        Instituição Financeira Nacional
# 1131  Instituição Financeira Internacional
# 1355       Instituição Financeira Nacional
# 1747       Instituição Financeira Nacional
# 1774       Instituição Financeira Nacional
# 2536  Instituição Financeira Internacional
# 2677  Instituição Financeira Internacional
# 2935       Instituição Financeira Nacional
# 3384  Instituição Financeira Internacional
# 3708  Instituição Financeira Internacional
# 3921  Instituição Financeira Internacional
# 4919       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 75    Banco Nacional de Desenvolvimento Econômico e ...           Real
# 494   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 1131            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 1355                                Banco do Brasil S/A           Real
# 1747  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 1774  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2536            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 2677                       Corporação Andina de Fomento  Dólar dos EUA
# 2935  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 3384                       Corporação Andina de Fomento  Dólar dos EUA
# 3708            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 3921            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 4919  Banco Nacional de Desenvolvimento Econômico e ...           Real
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 75    5.500000e+08                 1                      0  04/06/2012
# 494   3.200000e+09                 0                      0  26/12/2023
# 1131  1.157000e+08                 1                      0  06/04/2011
# 1355  1.537318e+09                 1                      0  26/02/2014
# 1747  4.000000e+07                 1                      0  23/12/2009
# 1774  1.354898e+09                 0                      0  22/01/2024
# 2536  1.000000e+07                 1                      0  06/03/2008
# 2677  5.500000e+08                 0                      0  31/05/2022
# 2935  1.200000e+09                 0                      0  16/04/2004
# 3384  2.040000e+08                 1                      0  27/02/2014
# 3708  2.000000e+07                 1                      0  07/07/2004
# 3921  1.624540e+08                 1                      0  25/08/2010
# 4919  9.220000e+08                 1                      0  19/04/2012

# %%
# 2) Seu código aqui
uf_consulta = 'MG'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta
# Out:
#       id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 682       13549           Estado  Minas Gerais        31  MG
# 1738      11328           Estado  Minas Gerais        31  MG
# 2213       7419           Estado  Minas Gerais        31  MG
# 2244       8255           Estado  Minas Gerais        31  MG
# 2364      10294           Estado  Minas Gerais        31  MG
# 2615      20534           Estado  Minas Gerais        31  MG
# 2900      22379           Estado  Minas Gerais        31  MG
# 2931       5828           Estado  Minas Gerais        31  MG
# 3989      13602           Estado  Minas Gerais        31  MG
# 4266       6811           Estado  Minas Gerais        31  MG
# 4622      10011           Estado  Minas Gerais        31  MG
#
#                    num_pvl                                             status  \
# 682                   None                                           Deferido
# 1738                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2213                  None                                           Deferido
# 2244                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2364                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2615  00000.000000/2017-69                     Arquivado por decurso de prazo
# 2900  00000.000000/2031-08                                 Arquivado pela STN
# 2931                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3989                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4266                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4622                  None                                           Deferido
#
#               num_processo        data_protocolo  \
# 682   19405.000023/2006-93  2006-05-19T03:00:00Z
# 1738  17944.001412/2012-51  2012-12-11T02:00:00Z
# 2213  17944.000571/2012-39  2012-06-18T03:00:00Z
# 2244  17944.000742/2013-19  2014-02-24T03:00:00Z
# 2364  17944.001163/2012-02  2012-10-17T03:00:00Z
# 2615  17944.001113/2015-60  2017-07-26T03:00:00Z
# 2900  17944.000548/2016-78  2016-12-21T02:00:00Z
# 2931  17944.000208/2013-02  2013-07-16T03:00:00Z
# 3989  19405.000034/2005-92  2005-10-31T02:00:00Z
# 4266  17944.000435/2008-62  2008-03-06T03:00:00Z
# 4622  17944.001099/2010-90  2010-08-23T03:00:00Z
#
#                                           tipo_operacao  \
# 682                         Operação contratual interna
# 1738  Operação contratual interna (com garantia da U...
# 2213                        Operação contratual interna
# 2244  Operação contratual interna (com garantia da U...
# 2364  Operação contratual interna (com garantia da U...
# 2615                        Operação contratual interna
# 2900  Operação contratual interna (com garantia da U...
# 2931  Operação contratual interna (com garantia da U...
# 3989  Operação contratual externa (com garantia da U...
# 4266  Operação contratual externa (com garantia da U...
# 4622                        Operação contratual interna
#
#                  finalidade                           tipo_credor  \
# 682          Infraestrutura       Instituição Financeira Nacional
# 1738         Multissetorial       Instituição Financeira Nacional
# 2213          BNDES Estados       Instituição Financeira Nacional
# 2244  Saneamento para Todos       Instituição Financeira Nacional
# 2364         Multissetorial       Instituição Financeira Nacional
# 2615                   PMAE       Instituição Financeira Nacional
# 2900     Aditivo contratual       Instituição Financeira Nacional
# 2931         Infraestrutura       Instituição Financeira Nacional
# 3989         Infraestrutura  Instituição Financeira Internacional
# 4266         Multissetorial  Instituição Financeira Internacional
# 4622                   PMAE       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 682                                 Banco do Brasil S/A           Iene
# 1738                                Banco do Brasil S/A           Real
# 2213  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2244                            Caixa Econômica Federal           Real
# 2364                                Banco do Brasil S/A           Real
# 2615  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2900                                Banco do Brasil S/A           Real
# 2931                                Banco do Brasil S/A           Real
# 3989            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 4266  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4622  Banco Nacional de Desenvolvimento Econômico e ...           Real
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 682   7.250000e+09                 1                      0  29/05/2006
# 1738  3.653733e+09                 1                      0  03/01/2013
# 2213  2.470000e+08                 1                      0  26/06/2012
# 2244  4.526420e+08                 1                      1  01/04/2014
# 2364  4.697730e+08                 1                      0  02/01/2013
# 2615  7.668000e+06                 0                      0  16/03/2018
# 2900  4.537330e+08                 0                      0  16/10/2017
# 2931  1.500000e+09                 1                      0  12/08/2013
# 3989  5.000000e+07                 1                      0  18/04/2006
# 4266  9.760000e+08                 1                      0  02/07/2008
# 4622  4.674243e+06                 1                      0  25/08/2010

# %%
resultado_consulta['status'].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    6
# Deferido                                                 3
# Arquivado por decurso de prazo                           1
# Arquivado pela STN                                       1
# Name: count, dtype: int64

# %%
status_MG = resultado_consulta['status'] == 'Arquivado por decurso de prazo'
status_MG.value_counts()
# Out:
# status
# False    10
# True      1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
uf_consulta = 'BA'
tipo_interessado_consulta = 'Município'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)

# %%
resultado_consulta['status'].value_counts()
# Out:
# status
# Deferido                                                 81
# Deferido (PVL-IF)                                        35
# Arquivado por decurso de prazo                           34
# Arquivado                                                25
# Regularizado                                              7
# Arquivado a pedido                                        5
# Encaminhado à PGFN com manifestação técnica favorável     5
# Em retificação pelo interessado                           3
# Indeferido                                                2
# Em retificação pelo credor (PVL-IF)                       1
# Arquivado pela STN                                        1
# Em retificação pelo credor                                1
# Pendente de regularização                                 1
# Name: count, dtype: int64

# %%
deferido_data = resultado_consulta[resultado_consulta['status'] == 'Deferido']

# %%
deferido_data
# Out:
#       id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 59         8445        Município                Camaçari   2905701  BA
# 89         6933        Município                Pintadas   2924652  BA
# 109        6964        Município                Pintadas   2924652  BA
# 173        7885        Município                Ubaitaba   2932200  BA
# 175        7914        Município             Cristópolis   2909703  BA
# ...         ...              ...                     ...       ...  ..
# 4492       6977        Município          Gentio do Ouro   2911303  BA
# 4581       8717        Município      Riachão do Jacuípe   2926301  BA
# 4694       7621        Município                Serrinha   2930501  BA
# 4754      38150        Município    Formosa do Rio Preto   2911105  BA
# 4922       7281        Município  Oliveira dos Brejinhos   2923209  BA
#
#                    num_pvl    status          num_processo  \
# 59                    None  Deferido  17944.000777/2014-21
# 89                    None  Deferido  17944.000461/2012-77
# 109                   None  Deferido  17944.000468/2012-99
# 173                   None  Deferido  17944.000672/2007-42
# 175                   None  Deferido  17944.000676/2009-92
# ...                    ...       ...                   ...
# 4492                  None  Deferido  17944.000471/2011-21
# 4581                  None  Deferido  17944.000830/2014-93
# 4694                  None  Deferido  17944.000621/2013-69
# 4754  PVL02.006750/2019-93  Deferido  17944.103551/2019-95
# 4922                  None  Deferido  17944.000537/2012-64
#
#             data_protocolo                tipo_operacao  \
# 59    2014-07-02T03:00:00Z  Operação contratual interna
# 89    2012-03-27T03:00:00Z  Operação contratual interna
# 109   2012-03-27T03:00:00Z  Operação contratual interna
# 173   2007-06-29T03:00:00Z  Operação contratual interna
# 175   2009-07-06T03:00:00Z  Operação contratual interna
# ...                    ...                          ...
# 4492  2011-05-03T03:00:00Z  Operação contratual interna
# 4581  2015-05-25T21:00:09Z  Operação contratual interna
# 4694  2013-08-16T03:00:00Z  Operação contratual interna
# 4754  2019-09-16T18:48:18Z  Operação contratual interna
# 4922  2012-04-09T03:00:00Z  Operação contratual interna
#
#                                           finalidade  \
# 59                               PAC - Contrapartida
# 89    Aquisição de máquinas, equipamentos e veículos
# 109                                   Infraestrutura
# 173                                          Provias
# 175   Aquisição de máquinas, equipamentos e veículos
# ...                                              ...
# 4492  Aquisição de máquinas, equipamentos e veículos
# 4581  Aquisição de máquinas, equipamentos e veículos
# 4694  Aquisição de máquinas, equipamentos e veículos
# 4754                                  Infraestrutura
# 4922  Aquisição de máquinas, equipamentos e veículos
#
#                           tipo_credor  \
# 59    Instituição Financeira Nacional
# 89    Instituição Financeira Nacional
# 109   Instituição Financeira Nacional
# 173   Instituição Financeira Nacional
# 175   Instituição Financeira Nacional
# ...                               ...
# 4492  Instituição Financeira Nacional
# 4581  Instituição Financeira Nacional
# 4694  Instituição Financeira Nacional
# 4754  Instituição Financeira Nacional
# 4922  Instituição Financeira Nacional
#
#                                          credor moeda       valor  \
# 59                      Caixa Econômica Federal  Real  15553250.2
# 89    Agência de Fomento do Estado da Bahia S/A  Real     65000.0
# 109   Agência de Fomento do Estado da Bahia S/A  Real    700000.0
# 173                         Banco do Brasil S/A  Real    462000.0
# 175   Agência de Fomento do Estado da Bahia S/A  Real     65000.0
# ...                                         ...   ...         ...
# 4492  Agência de Fomento do Estado da Bahia S/A  Real   1500000.0
# 4581  Agência de Fomento do Estado da Bahia S/A  Real    400000.0
# 4694  Agência de Fomento do Estado da Bahia S/A  Real    195000.0
# 4754  Agência de Fomento do Estado da Bahia S/A  Real   5900000.0
# 4922  Agência de Fomento do Estado da Bahia S/A  Real    170000.0
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 59                   1                      0  04/08/2014
# 89                   0                      0  16/05/2012
# 109                  0                      0  16/05/2012
# 173                  0                      0  09/07/2007
# 175                  0                      0  09/07/2009
# ...                ...                    ...         ...
# 4492                 0                      0  01/06/2011
# 4581                 0                      0  17/06/2015
# 4694                 0                      0  29/08/2013
# 4754                 0                      1  24/09/2019
# 4922                 1                      0  18/05/2012
#
# [81 rows x 18 columns]

# %%
contagem_deferido_por_municipio = deferido_data['interessado'].value_counts()
contagem_deferido_por_municipio.head()
# Out:
# interessado
# Camaçari              3
# Riachão do Jacuípe    3
# Lauro de Freitas      2
# Santo Estêvão         2
# Pintadas              2
# Name: count, dtype: int64

# %%
# 4) Seu código aqui
uf_consulta = 'BA'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta.to_csv('Solicitações_Bahia.csv')
